# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                           1.5                             11
# 1                           2.5                             11
# 2                           2.5                             11
# 3                           3.5                             11
# 4                           3.5                             11
#
#   "Delighted Members" Purchase
# 0                          Yes
# 1                           No
# 2                           No
# 3                           No
# 4                           No

# %%
df[(df["Average Delivery Rating (a1)"] < 3) & (df['"Delighted Members" Purchase'] == "No")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 1                            2.5                             11
# 2                            2.5                             11
# 7                            2.5                             13
# 8                            2.5                             13
# 13                           2.5                             15
# 14                           2.5                             15
# 18                           1.5                             27
# 24                           1.5                             39
#
#    "Delighted Members" Purchase
# 1                            No
# 2                            No
# 7                            No
# 8                            No
# 13                           No
# 14                           No
# 18                           No
# 24                           No

# %%
df[(df["Average Delivery Rating (a1)"] < 3) & (df['"Delighted Members" Purchase'] == "Yes")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 6                            1.5                             13
# 12                           1.5                             15
# 19                           2.5                             27
# 20                           2.5                             27
# 25                           2.5                             39
# 26                           2.5                             39
#
#    "Delighted Members" Purchase
# 0                           Yes
# 6                           Yes
# 12                          Yes
# 19                          Yes
# 20                          Yes
# 25                          Yes
# 26                          Yes

# %%
df[(df["Average Delivery Rating (a1)"] > 3) & (df['"Delighted Members" Purchase'] == "No")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 3                            3.5                             11
# 4                            3.5                             11
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 15                           3.5                             15
# 16                           3.5                             15
#
#    "Delighted Members" Purchase
# 3                            No
# 4                            No
# 9                            No
# 10                           No
# 11                           No
# 15                           No
# 16                           No

# %%
df[(df["Average Delivery Rating (a1)"] > 3) & (df['"Delighted Members" Purchase'] == "Yes")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 5                            4.5                             11
# 17                           4.5                             15
# 21                           3.5                             27
# 22                           4.5                             27
# 23                           4.5                             27
# 27                           3.5                             39
# 28                           4.5                             39
# 29                           4.5                             39
#
#    "Delighted Members" Purchase
# 5                           Yes
# 17                          Yes
# 21                          Yes
# 22                          Yes
# 23                          Yes
# 27                          Yes
# 28                          Yes
# 29                          Yes

# %%
df[(df["Average Orders per month (a2)"] < 20)].shape
# Out:
# (18, 3)

# %%
df[(df["Average Orders per month (a2)"] < 20) & (df['"Delighted Members" Purchase'] == "Yes")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 5                            4.5                             11
# 6                            1.5                             13
# 12                           1.5                             15
# 17                           4.5                             15
#
#    "Delighted Members" Purchase
# 0                           Yes
# 5                           Yes
# 6                           Yes
# 12                          Yes
# 17                          Yes

# %%
df[(df["Average Orders per month (a2)"] < 20) & (df['"Delighted Members" Purchase'] == "No")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 1                            2.5                             11
# 2                            2.5                             11
# 3                            3.5                             11
# 4                            3.5                             11
# 7                            2.5                             13
# 8                            2.5                             13
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 13                           2.5                             15
# 14                           2.5                             15
# 15                           3.5                             15
# 16                           3.5                             15
#
#    "Delighted Members" Purchase
# 1                            No
# ...

# %%
df[(df["Average Orders per month (a2)"] > 20)]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 18                           1.5                             27
# 19                           2.5                             27
# 20                           2.5                             27
# 21                           3.5                             27
# 22                           4.5                             27
# 23                           4.5                             27
# 24                           1.5                             39
# 25                           2.5                             39
# 26                           2.5                             39
# 27                           3.5                             39
# 28                           4.5                             39
# 29                           4.5                             39
#
#    "Delighted Members" Purchase
# 18                           No
# 19                          Yes
# 20                          Yes
# ...

# %%
df[(df["Average Orders per month (a2)"] > 20) & (df['"Delighted Members" Purchase'] == "Yes")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 19                           2.5                             27
# 20                           2.5                             27
# 21                           3.5                             27
# 22                           4.5                             27
# 23                           4.5                             27
# 25                           2.5                             39
# 26                           2.5                             39
# 27                           3.5                             39
# 28                           4.5                             39
# 29                           4.5                             39
#
#    "Delighted Members" Purchase
# 19                          Yes
# 20                          Yes
# 21                          Yes
# 22                          Yes
# 23                          Yes
# 25                          Yes
# ...

# %%
df[(df["Average Orders per month (a2)"] > 20) & (df['"Delighted Members" Purchase'] == "No")]
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 18                           1.5                             27
# 24                           1.5                             39
#
#    "Delighted Members" Purchase
# 18                           No
# 24                           No
